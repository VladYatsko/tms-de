# %% [markdown]
# #### DB Task

# %% [markdown]
# ##### Subtask 1

# %%
import sqlite3
import pandas as pd

# %% [markdown]
# ###### Printing each DF

# %%
with sqlite3.connect('database.db') as conn:
    clients_df = pd.read_sql('SELECT * FROM main.clients', conn)

clients_df
# Out:
#    client_id       name  age     city  account_number
# 0          1    Василий   34    Минск            1001
# 1          2  Екатерина   28   Москва            1002
# 2          3      Мария   45   Гродно            1003
# 3          4     Михаил   37  Витебск            1004
# 4          5    Евгения   29    Минск            1005

# %%
with sqlite3.connect('database.db') as conn:
    balance_df = pd.read_sql("SELECT * FROM main.balance", conn)

balance_df
# Out:
#    client_id  amount
# 0          1    1000
# 1          2    1500
# 2          3     800
# 3          4    2000
# 4          5    1200

# %%
with sqlite3.connect('database.db') as conn:
    transactions_df = pd.read_sql("SELECT * FROM main.transactions", conn)
    
transactions_df
# Out:
#    transaction_id  client_id        date  amount        type  \
# 0               1          1  2025-03-01     150     deposit
# 1               2          1  2025-03-02     -50  withdrawal
# 2               3          2  2025-03-01     200     deposit
# 3               4          2  2025-03-03     -30  withdrawal
# 4               5          3  2025-03-02     100     deposit
# 5               6          3  2025-03-04     -20  withdrawal
# 6               7          4  2025-03-03     300     deposit
# 7               8          4  2025-03-05     -70  withdrawal
# 8               9          5  2025-03-04     250     deposit
# 9              10          5  2025-03-06     -40  withdrawal
#
#             description
# 0                Salary
# 1        ATM withdrawal
# 2     Freelance payment
# 3         Grocery store
# 4  Transfer from friend
# 5           Coffee shop
# 6                 Bonus
# 7            Restaurant
# 8     Investment return
# 9              Shopping

# %%
print(clients_df[clients_df['city'] == 'Минск']['age'].mean())
# Out:
# 31.5

# %% [markdown]
# ##### Subtask 2

# %%
high_balance_df = balance_df[balance_df['amount'] > 1000]
high_balance_df
# Out:
#    client_id  amount
# 1          2    1500
# 3          4    2000
# 4          5    1200

# %% [markdown]
# ##### Subtask 3

# %%
types_df = transactions_df.groupby('type')['type'].count()
types_df
# Out:
# type
# deposit       5
# withdrawal    5
# Name: type, dtype: int64

# %% [markdown]
# ##### Subtask 4

# %%
transactions_df['amount'] = pd.to_numeric(transactions_df['amount'], errors='coerce')
print(transactions_df.groupby('client_id')['amount'].min().sort_values(ascending=True))
# Out:
# client_id
# 4   -70
# 1   -50
# 5   -40
# 2   -30
# 3   -20
# Name: amount, dtype: int64

# %% [markdown]
# ##### Subtask 5

# %%
number_of_transactions_df = (transactions_df.groupby('client_id').count()
                             .sort_values(ascending=False, by='client_id'))

number_of_transactions_df.iloc[:3]
# Out:
#            transaction_id  date  amount  type  description
# client_id
# 5                       2     2       2     2            2
# 4                       2     2       2     2            2
# 3                       2     2       2     2            2

# %% [markdown]
# ##### Subtask 6

# %%
merged_df = transactions_df.merge(balance_df, how='left', on='client_id')

merged_df
# Out:
#    transaction_id  client_id        date  amount_x        type  \
# 0               1          1  2025-03-01       150     deposit
# 1               2          1  2025-03-02       -50  withdrawal
# 2               3          2  2025-03-01       200     deposit
# 3               4          2  2025-03-03       -30  withdrawal
# 4               5          3  2025-03-02       100     deposit
# 5               6          3  2025-03-04       -20  withdrawal
# 6               7          4  2025-03-03       300     deposit
# 7               8          4  2025-03-05       -70  withdrawal
# 8               9          5  2025-03-04       250     deposit
# 9              10          5  2025-03-06       -40  withdrawal
#
#             description  amount_y
# 0                Salary      1000
# 1        ATM withdrawal      1000
# 2     Freelance payment      1500
# 3         Grocery store      1500
# 4  Transfer from friend       800
# 5           Coffee shop       800
# 6                 Bonus      2000
# 7            Restaurant      2000
# 8     Investment return      1200
# 9              Shopping      1200

# %%
merged_df['amount_x'] = pd.to_numeric(merged_df['amount_x'], errors='coerce')
merged_df['amount_y'] = pd.to_numeric(merged_df['amount_y'], errors='coerce')

# %%
merged_df['percentage'] = merged_df['amount_x'] * 100 / merged_df['amount_y']

merged_df
# Out:
#    transaction_id  client_id        date  amount_x        type  \
# 0               1          1  2025-03-01       150     deposit
# 1               2          1  2025-03-02       -50  withdrawal
# 2               3          2  2025-03-01       200     deposit
# 3               4          2  2025-03-03       -30  withdrawal
# 4               5          3  2025-03-02       100     deposit
# 5               6          3  2025-03-04       -20  withdrawal
# 6               7          4  2025-03-03       300     deposit
# 7               8          4  2025-03-05       -70  withdrawal
# 8               9          5  2025-03-04       250     deposit
# 9              10          5  2025-03-06       -40  withdrawal
#
#             description  amount_y  percentage
# 0                Salary      1000   15.000000
# 1        ATM withdrawal      1000   -5.000000
# 2     Freelance payment      1500   13.333333
# 3         Grocery store      1500   -2.000000
# 4  Transfer from friend       800   12.500000
# 5           Coffee shop       800   -2.500000
# 6                 Bonus      2000   15.000000
# 7            Restaurant      2000   -3.500000
# 8     Investment return      1200   20.833333
# 9              Shopping      1200   -3.333333

# %%
suspicious_df = merged_df[(merged_df['percentage'] > 15) |
                          (merged_df['percentage'] < -10)]

suspicious_df
# Out:
#    transaction_id  client_id        date  amount_x     type  \
# 8               9          5  2025-03-04       250  deposit
#
#          description  amount_y  percentage
# 8  Investment return      1200   20.833333
