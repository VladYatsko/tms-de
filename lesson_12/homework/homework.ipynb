# %% [markdown]
# #### Task 1

# %%
import pandas as pd


df = pd.read_csv('..\\classwork\\hw_DE_12.csv')

df
# Out:
#        id first_name  last_name                        email   gender  \
# 0       1    Zebulon     Sheara        zsheara0@buzzfeed.com     Male
# 1       2      Gabby      Hundy           ghundy1@dyndns.org     Male
# 2       3     Zaneta    Macewan         zmacewan2@dyndns.org   Female
# 3       4       Linn     Steely             lsteely3@psu.edu     Male
# 4       5     Althea      Segar            asegar4@prlog.org   Female
# ..    ...        ...        ...                          ...      ...
# 995   996    Zsa zsa  McGarahan  zmcgarahanrn@craigslist.org   Female
# 996   997         Al   Villiers  avilliersro@nydailynews.com  Agender
# 997   998   Natalina  Clavering        nclaveringrp@jugem.jp   Female
# 998   999     Gretta  Witheford   gwithefordrq@discovery.com   Female
# 999  1000      Tadio   Feighney        tfeighneyrr@google.es     Male
#
#          ip_address
# 0    26.254.115.173
# 1    86.222.142.186
# 2      20.98.185.65
# 3    65.253.237.106
# ...

# %%
female_df = df[(df.gender == 'Female') & df.ip_address.str.startswith('1')][['first_name', 'last_name']]

female_df
# Out:
#     first_name   last_name
# 8        Kaile  Clementson
# 10      Melosa     Boneham
# 11       Deina    Frisdick
# 15       Mamie  Wainwright
# 25      Ysabel  Aitchinson
# ..         ...         ...
# 980     Pennie     Itzhaki
# 984       Lula       Almon
# 989  Francesca    Shorrock
# 993  Morganica     Pierton
# 997   Natalina   Clavering
#
# [216 rows x 2 columns]

# %% [markdown]
# #### Task 2

# %%
df = pd.read_csv('..\\classwork\\hw_DE_12.csv')

df
# Out:
#        id first_name  last_name                        email   gender  \
# 0       1    Zebulon     Sheara        zsheara0@buzzfeed.com     Male
# 1       2      Gabby      Hundy           ghundy1@dyndns.org     Male
# 2       3     Zaneta    Macewan         zmacewan2@dyndns.org   Female
# 3       4       Linn     Steely             lsteely3@psu.edu     Male
# 4       5     Althea      Segar            asegar4@prlog.org   Female
# ..    ...        ...        ...                          ...      ...
# 995   996    Zsa zsa  McGarahan  zmcgarahanrn@craigslist.org   Female
# 996   997         Al   Villiers  avilliersro@nydailynews.com  Agender
# 997   998   Natalina  Clavering        nclaveringrp@jugem.jp   Female
# 998   999     Gretta  Witheford   gwithefordrq@discovery.com   Female
# 999  1000      Tadio   Feighney        tfeighneyrr@google.es     Male
#
#          ip_address
# 0    26.254.115.173
# 1    86.222.142.186
# 2      20.98.185.65
# 3    65.253.237.106
# ...

# %%
df['domain'] = df['email'].str.split('@').str[1]

df
# Out:
#        id first_name  last_name                        email   gender  \
# 0       1    Zebulon     Sheara        zsheara0@buzzfeed.com     Male
# 1       2      Gabby      Hundy           ghundy1@dyndns.org     Male
# 2       3     Zaneta    Macewan         zmacewan2@dyndns.org   Female
# 3       4       Linn     Steely             lsteely3@psu.edu     Male
# 4       5     Althea      Segar            asegar4@prlog.org   Female
# ..    ...        ...        ...                          ...      ...
# 995   996    Zsa zsa  McGarahan  zmcgarahanrn@craigslist.org   Female
# 996   997         Al   Villiers  avilliersro@nydailynews.com  Agender
# 997   998   Natalina  Clavering        nclaveringrp@jugem.jp   Female
# 998   999     Gretta  Witheford   gwithefordrq@discovery.com   Female
# 999  1000      Tadio   Feighney        tfeighneyrr@google.es     Male
#
#          ip_address           domain
# 0    26.254.115.173     buzzfeed.com
# 1    86.222.142.186       dyndns.org
# ...

# %%
df.shape[0]
# Out:
# 1000

# %% [markdown]
# #### Task 3

# %%
unique_domains_series = pd.Series(df['domain'].unique()).to_frame()

unique_domains_series
# Out:
#                           0
# 0              buzzfeed.com
# 1                dyndns.org
# 2                   psu.edu
# 3                 prlog.org
# 4               mozilla.org
# ..                      ...
# 430             tinypic.com
# 431              taobao.com
# 432  nationalgeographic.com
# 433  scientificamerican.com
# 434               google.es
#
# [435 rows x 1 columns]

# %%
unique_domains_series.shape[0]
# Out:
# 435
